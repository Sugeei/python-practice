# %% [markdown]
# ##### homepage: http://pandas.pydata.org/index.html

# %% [markdown]
# # Indexing and Selecting Data

# %%
# https://pandas.pydata.org/pandas-docs/stable/indexing.html

# %% [markdown]
# # Basic

# %% [markdown]
# ### 读入数据

# %%
import pandas as pd
import warnings
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# df1 = pd.read_csv("./trainset/pcdata_0611.csv") # read_sql read_html

# %% [markdown]
# ### 生成DataFrame

# %%
pd.DataFrame({'A': [1, 2, 3],
              'B': [4, 5, 6]},  
                    index=list('abc'))
# Out:
#    A  B
# a  1  4
# b  2  5
# c  3  6

# %%
pd.DataFrame([[1, 2, 3],
              [4, 5, 6]],
                    index=list('ab'))
# Out:
#    0  1  2
# a  1  2  3
# b  4  5  6

# %%
dfd = pd.DataFrame({'A': [1, 2, 3],
                    'B': [4, 5, 6]},  
                    index=list('abc'))
dfd
# Out:
#    A  B
# a  1  4
# b  2  5
# c  3  6

# %% [markdown]
# ### .T
# Transpose

# %%
dfd.T
# Out:
#    a  b  c
# A  1  2  3
# B  4  5  6

# %% [markdown]
# ### Index

# %%
dfd[["A","B"]]
# Out:
#    A  B
# a  1  4
# b  2  5
# c  3  6

# %%
dfd[1:2]
# Out:
#    A  B  C
# b  2  5  7

# %%
dfd[::2]
# Out:
#    A  B  C
# a  1  4  5
# c  3  6  9

# %% [markdown]
# ### new column

# %%
tdf = dfd
tdf["C"] = tdf["A"] + tdf["B"]
tdf
# Out:
#    A  B  C
# a  1  4  5
# b  2  5  7
# c  3  6  9

# %% [markdown]
# ### new row

# %%
tdf.append(pd.DataFrame([[2,4,6]], columns=["A","B","C"]))
# Out:
#    A  B  C
# a  1  4  5
# b  2  5  7
# c  3  6  9
# 0  2  4  6

# %%
# tdf2.reset_index()
# Out:
#   index  A  B  C
# 0     a  1  4  5
# 1     b  2  5  7
# 2     c  3  6  9
# 3     0  2  4  6

# %%
tdf.append(tdf)
# Out:
#    A  B  C
# a  1  4  5
# b  2  5  7
# c  3  6  9
# a  1  4  5
# b  2  5  7
# c  3  6  9

# %% [markdown]
# ### .concat
# more efficient than append
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.concat.html?highlight=concat#pandas.concat

# %%
pd.concat([tdf, tdf])
# Out:
#    A  B  C
# a  1  4  5
# b  2  5  7
# c  3  6  9
# a  1  4  5
# b  2  5  7
# c  3  6  9

# %%
pd.concat([tdf, tdf], ignore_index=True)
# Out:
#    A  B  C
# 0  1  4  5
# 1  2  5  7
# 2  3  6  9
# 3  1  4  5
# 4  2  5  7
# 5  3  6  9

# %% [markdown]
# ##### axis : {0/’index’, 1/’columns’}, default 0
#
#     The axis to concatenate along

# %%
pd.concat([tdf, tdf], axis=1)
# Out:
#    A  B  C  A  B  C
# a  1  4  5  1  4  5
# b  2  5  7  2  5  7
# c  3  6  9  3  6  9

# %% [markdown]
# ### seclect

# %%
dfd
# Out:
#    A  B  C
# a  1  4  5
# b  2  5  7
# c  3  6  9

# %%
dfd[dfd.A>1]
# Out:
#    A  B
# b  2  5
# c  3  6

# %%
dfd.A>1
# Out:
# a    False
# b     True
# c     True
# Name: A, dtype: bool

# %%
filter = dfd.A>1
type(filter)
# Out:
# pandas.core.series.Series

# %%
# dfd[dfd.C > dfd.A]
# Out:
#    A  B  C
# a  1  4  5
# b  2  5  7
# c  3  6  9

# %% [markdown]
# ### .loc
# df.loc[row_indexer,column_indexer]

# %%
dates = pd.date_range('1/1/2000', periods=8)

df = pd.DataFrame(np.random.randn(8, 4), index=dates, columns=['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2000-01-01 -1.170045  1.282054  1.156002  0.116517
# 2000-01-02 -0.211171  0.687866 -0.335056  0.931112
# 2000-01-03 -0.092936 -0.326598  0.198455  0.950900
# 2000-01-04 -0.372172  0.356238  0.464020 -1.085201
# 2000-01-05 -0.483648  1.749823  0.487370 -0.409341
# 2000-01-06  0.498361  0.127934  1.542690 -0.103222
# 2000-01-07 -1.153640  0.877413 -0.447568  0.493444
# 2000-01-08  1.614527 -0.151379  0.140525 -1.280825

# %% [markdown]
# ### column index

# %%
# df.loc[:]

# %%
# note the difference between with and without the brackets
df1 = df.loc[:, ['A']]
print type(df1)
df2 = df.loc[:, 'A']
print type(df2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### row index

# %%
filters = df.index>'2000-01-05'
df.loc[filters, :]
# Out:
#                    A         B         C         D
# 2000-01-06  0.944588 -0.683064  0.313358 -0.432203
# 2000-01-07 -1.448672 -0.564808 -1.025435  0.095750
# 2000-01-08 -0.093160 -0.980160  0.242726  0.110485

# %% [markdown]
# ##### String likes in slicing can be convertible to the type of the index and lead to natural slicing.

# %%
df.loc['20000101':'20000105']
# Out:
#                    A         B         C         D
# 2000-01-01  1.519277  1.582809  0.643310  0.969700
# 2000-01-02  1.141639  2.073245  0.238348  0.504121
# 2000-01-03  0.294490 -0.345567  0.793849  1.585689
# 2000-01-04  1.747291 -0.075140 -0.122804  1.125318
# 2000-01-05  0.649874  0.415495 -1.801074 -0.385598

# %%
# df.loc[:3]

# %% [markdown]
# ##### .index

# %%
df.index[[0, 2]]
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-03'], dtype='datetime64[ns]', freq=None)

# %%
df.loc[df.index[[0, 2]],['A']]
# Out:
#                    A
# 2000-01-01 -0.001379
# 2000-01-03 -0.295811

# %% [markdown]
# ### .iloc

# %%
df.iloc[:3]
# Out:
#                    A         B         C         D
# 2000-01-01  0.490313 -1.826382 -0.847263  0.347326
# 2000-01-02  0.160241  0.510906 -0.686736  0.435970
# 2000-01-03 -0.274126 -1.398118 -1.205558  1.423482

# %%
df.iloc[:3, 2:4]
# Out:
#                    C         D
# 2000-01-01 -0.847263  0.347326
# 2000-01-02 -0.686736  0.435970
# 2000-01-03 -1.205558  1.423482

# %% [markdown]
# ##### .get_loc

# %%
df.columns.get_loc('A')
# Out:
# 0

# %%
df.iloc[[0, 2], [df.columns.get_loc('A')]]
# Out:
#                    A
# 2000-01-01 -0.001379
# 2000-01-03 -0.295811

# %% [markdown]
# ##### .get_indexer
# For getting multiple indexers

# %%
df.columns.get_indexer(['A', 'B'])
# Out:
# array([0, 1], dtype=int64)

# %%
df.iloc[[0, 2], df.columns.get_indexer(['A', 'B'])]
# Out:
#                    A         B
# 2000-01-01 -0.001379  1.274753
# 2000-01-03 -0.295811 -0.191541

# %% [markdown]
# ### .loc vs .iloc
# https://stackoverflow.com/questions/31593201/pandas-iloc-vs-ix-vs-loc-explanation

# %%
df2 = df.reset_index(drop=True)
df2 = df2.sort_values("A")
df2
# Out:
#           A         B         C         D
# 5 -1.029617 -0.518464  0.497126  0.234901
# 1 -0.779598  0.664122  0.422424 -2.376949
# 4 -0.323552  0.545701  0.724448 -1.213677
# 2 -0.295811 -0.191541 -1.380574  0.596739
# 3 -0.261907  0.071790 -1.758331 -0.666785
# 0 -0.001379  1.274753  2.213789 -0.877540
# 6  0.627716  1.396828 -0.105753 -0.279644
# 7  1.465338  0.419214  0.231632  1.753904

# %%
df2.loc[:3]
# Out:
#           A         B         C         D
# 5 -1.029617 -0.518464  0.497126  0.234901
# 1 -0.779598  0.664122  0.422424 -2.376949
# 4 -0.323552  0.545701  0.724448 -1.213677
# 2 -0.295811 -0.191541 -1.380574  0.596739
# 3 -0.261907  0.071790 -1.758331 -0.666785

# %%
# df2.loc[:1, ['A','C']]

# %%
df2.iloc[:3]
# Out:
#           A         B         C         D
# 5 -1.029617 -0.518464  0.497126  0.234901
# 1 -0.779598  0.664122  0.422424 -2.376949
# 4 -0.323552  0.545701  0.724448 -1.213677

# %%
# df2.iloc[:1, :3]

# %% [markdown]
# ### .ix
# starting from Pandas 0.20.1 the .ix indexer is deprecated, in favor of the more strict .iloc and .loc indexers.

# %% [markdown]
# ### .ix vs .iloc vs .loc
# https://stackoverflow.com/questions/31593201/pandas-iloc-vs-ix-vs-loc-explanation-how-are-they-different

# %% [markdown]
# ### Different Choices for Indexing
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#different-choices-for-indexing

# %% [markdown]
# ### .reset_index
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.reset_index.html?highlight=reset_index

# %%
# df

# %%
df.reset_index()
# Out:
#        index         A         B         C         D
# 0 2000-01-01  1.519277  1.582809  0.643310  0.969700
# 1 2000-01-02  1.141639  2.073245  0.238348  0.504121
# 2 2000-01-03  0.294490 -0.345567  0.793849  1.585689
# 3 2000-01-04  1.747291 -0.075140 -0.122804  1.125318
# 4 2000-01-05  0.649874  0.415495 -1.801074 -0.385598
# 5 2000-01-06  0.944588 -0.683064  0.313358 -0.432203
# 6 2000-01-07 -1.448672 -0.564808 -1.025435  0.095750
# 7 2000-01-08 -0.093160 -0.980160  0.242726  0.110485

# %% [markdown]
# ##### Q: how to aviod old index being added as a column?

# %%
# df.reset_index()

# %%
df2 = df.reset_index(drop=True)
df2
# Out:
#           A         B         C         D
# 0  1.519277  1.582809  0.643310  0.969700
# 1  1.141639  2.073245  0.238348  0.504121
# 2  0.294490 -0.345567  0.793849  1.585689
# 3  1.747291 -0.075140 -0.122804  1.125318
# 4  0.649874  0.415495 -1.801074 -0.385598
# 5  0.944588 -0.683064  0.313358 -0.432203
# 6 -1.448672 -0.564808 -1.025435  0.095750
# 7 -0.093160 -0.980160  0.242726  0.110485

# %%
df2.loc[:3]
# Out:
#           A         B         C         D
# 0 -1.029617 -0.518464  0.497126  0.234901
# 1 -0.779598  0.664122  0.422424 -2.376949
# 2 -0.323552  0.545701  0.724448 -1.213677
# 3 -0.295811 -0.191541 -1.380574  0.596739

# %%
df2.iloc[:3]
# Out:
#           A         B         C         D
# 0 -1.029617 -0.518464  0.497126  0.234901
# 1 -0.779598  0.664122  0.422424 -2.376949
# 2 -0.323552  0.545701  0.724448 -1.213677

# %% [markdown]
# ### .set_index
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.set_index.html?highlight=set_index

# %%
tdf = df.reset_index()
tdf.set_index("index")
# Out:
#                    A         B         C         D
# index
# 2000-01-01  1.519277  1.582809  0.643310  0.969700
# 2000-01-02  1.141639  2.073245  0.238348  0.504121
# 2000-01-03  0.294490 -0.345567  0.793849  1.585689
# 2000-01-04  1.747291 -0.075140 -0.122804  1.125318
# 2000-01-05  0.649874  0.415495 -1.801074 -0.385598
# 2000-01-06  0.944588 -0.683064  0.313358 -0.432203
# 2000-01-07 -1.448672 -0.564808 -1.025435  0.095750
# 2000-01-08 -0.093160 -0.980160  0.242726  0.110485

# %%
tdf = df.reset_index()
tdf.set_index("A")
# Out:
#                index         B         C         D
# A
#  1.519277 2000-01-01  1.582809  0.643310  0.969700
#  1.141639 2000-01-02  2.073245  0.238348  0.504121
#  0.294490 2000-01-03 -0.345567  0.793849  1.585689
#  1.747291 2000-01-04 -0.075140 -0.122804  1.125318
#  0.649874 2000-01-05  0.415495 -1.801074 -0.385598
#  0.944588 2000-01-06 -0.683064  0.313358 -0.432203
# -1.448672 2000-01-07 -0.564808 -1.025435  0.095750
# -0.093160 2000-01-08 -0.980160  0.242726  0.110485

# %% [markdown]
# ### .merge

# %%
dfa = pd.DataFrame({'key': ["foo","bar","baz"],
                    'v1': [4, 5, 6]})
dfb = pd.DataFrame({'key': ["foo","bar","qux"],
                    'v2': [1, 2, 3]})

# %%
dfa
# Out:
#    key  v1
# 0  foo   4
# 1  bar   5
# 2  baz   6

# %%
dfb
# Out:
#    key  v2
# 0  foo   1
# 1  bar   2
# 2  qux   3

# %%
dfa.merge(dfb, on="key")
# Out:
#    key  v1  v2
# 0  foo   4   1
# 1  bar   5   2

# %% [markdown]
# ### trick

# %% [markdown]
# ##### _merge
# indicator

# %% [markdown]
# ##### Q: How to get rows that appear in dfa but not dfb ?

# %%
pd.merge(dfa, dfb, how='outer',indicator=True)
# Out:
#    key   v1   v2      _merge
# 0  foo  4.0  1.0        both
# 1  bar  5.0  2.0        both
# 2  baz  6.0  NaN   left_only
# 3  qux  NaN  3.0  right_only

# %% [markdown]
# ### method chaining

# %%
pd.merge(dfa, dfb, how='outer',
indicator=True)
.query('_merge == "left_only"')
.drop(['_merge'],axis=1)

# %% [markdown]
# ### .isin

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': ['a', 'b', 'f']})
df
# Out:
#    A  B
# 0  1  a
# 1  2  b
# 2  3  f

# %%
df.isin({"A": [1,3,5]})
# Out:
#        A      B
# 0   True  False
# 1  False  False
# 2   True  False

# %%
df[df.A.isin([1,3,5])]
# Out:
#    A  B
# 0  1  a
# 2  3  f

# %% [markdown]
# # example

# %% [markdown]
# ### .read_csv
# fund style 20171229

# %%
style = pd.read_csv('20171229.csv')
style.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3089 entries, 0 to 3088
# Data columns (total 5 columns):
# SECURITY_ID_INT    3089 non-null int64
# raw_X              3089 non-null float64
# raw_Y              3089 non-null float64
# vertical           3089 non-null object
# horizontal         3089 non-null object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 120.7+ KB

# %%
style.head(5)
# Out:
#    SECURITY_ID_INT       raw_X       raw_Y vertical horizontal
# 0             1734 -106.512730  223.595615    large      value
# 1             1351  -95.753155  244.328818    large      value
# 2             2228  -74.231371  318.054976    large      value
# 3             2296  -57.797931  394.503697    large      value
# 4             1971  -50.873616  581.970420    large      value

# %% [markdown]
# ### .sort_values
# ascending : default True
# inplace : bool, default False
#
#     if True, perform operation in-place

# %%
style.sort_values("SECURITY_ID_INT", inplace=True)
style.head(10)
# Out:
#       SECURITY_ID_INT       raw_X       raw_Y vertical horizontal
# 40                  2   54.546833  432.316244    large      value
# 409                 4  251.404177  469.568402    large     growth
# 1627                8  241.797552   -7.651046    small     growth
# 1754               10  310.086762   69.951089    small     growth
# 2072               12   -8.259759  171.692515      mid      value
# 1479               14  202.552752   95.194638    small     growth
# 503                16  319.352339  228.303999    large     growth
# 2308               17   99.307138  185.975849      mid      value
# 1829               19  370.285031   71.223713    small     growth
# 2831               21  245.231469  145.630078      mid     growth

# %% [markdown]
# ### .reset_index

# %%
# style.reset_index(inplace=True)
style.reset_index(inplace=True, drop=True )

# style.head(20)
style
# Out:
#       SECURITY_ID_INT       raw_X       raw_Y vertical horizontal
# 0                   2   54.546833  432.316244    large      value
# 1                   4  251.404177  469.568402    large     growth
# 2                   8  241.797552   -7.651046    small     growth
# 3                  10  310.086762   69.951089    small     growth
# 4                  12   -8.259759  171.692515      mid      value
# 5                  14  202.552752   95.194638    small     growth
# 6                  16  319.352339  228.303999    large     growth
# 7                  17   99.307138  185.975849      mid      value
# 8                  19  370.285031   71.223713    small     growth
# 9                  21  245.231469  145.630078      mid     growth
# 10                 24  229.214039  213.537403    large     growth
# 11                 27  217.547296    5.712293    small     growth
# 12                 29   69.422993  180.208746      mid      value
# 13                 31  307.993202   47.180633    small     growth
# 14                 33  140.911334  149.106156      mid       core
# 15                 35  225.120801   99.295289    small     growth
# 16                 37  216.232175   61.737654    small     growth
# 17                 39  131.995782  178.453363      mid       core
# 18                 40   38.098065  186.122212      mid      value
# 19                 42  196.427229   30.470158    small       core
# 20                 45  435.158430  157.968294      mid     growth
# 21                 47   48.931203   82.228504    small      value
# 22                 49   62.086052  225.910695    large      value
# 23                 50  312.964303  232.425854    large     growth
# 24                 52  351.132229  156.775034      mid     growth
# 25                 54   20.195345  149.940261      mid      value
# 26                 56  112.504623  179.690342      mid       core
# 27                 57   97.199483   67.094573    small      value
# 28                 59  235.493535  177.245325      mid     growth
# 29                 60  156.006193  136.746889      mid       core
# ...               ...         ...         ...      ...        ...
# 3059           608872  442.265754   71.499941    small     growth
# 3060           609349  315.788800   28.266672    small     growth
# 3061           643126  447.950597   46.150897    small     growth
# 3062           697375  437.383476   98.024508    small     growth
# 3063           706318  297.749454   13.626934    small     growth
# 3064           720082  482.392971   94.807866    small     growth
# 3065           720408  507.102996   73.238187    small     growth
# 3066           722866  530.968258  118.408305      mid     growth
# 3067           731081  367.668954   71.963050    small     growth
# 3068           841088  359.416606    9.737626    small     growth
# 3069           948673   64.220106   91.251065    small      value
# 3070           984382  282.926912   27.808847    small     growth
# 3071         30000186  128.094265  267.550670    large       core
# 3072         30004642  321.823022   32.414554    small     growth
# 3073         30004657  307.281947   45.985362    small     growth
# 3074         30004658  327.565190   16.862841    small     growth
# 3075         30004664  512.740054   70.565145    small     growth
# 3076         30004666   47.021335   29.635418    small      value
# 3077         30004690  475.533539   48.545333    small     growth
# 3078         30004703  417.981804   63.743232    small     growth
# 3079         30004704  133.410300   23.698856    small       core
# 3080         30004705  521.568351   55.521179    small     growth
# 3081         30004706  431.930095   11.843375    small     growth
# 3082         30005207  258.001936  226.612383    large     growth
# 3083         30011845  515.683759   51.987300    small     growth
# 3084         30011852  279.934828   24.220374    small     growth
# 3085         30011859  330.412682   23.172880    small     growth
# 3086         30011864  507.286792  103.169565      mid     growth
# 3087         30011866  399.720301   21.900410    small     growth
# 3088         30011876  189.041079   62.886531    small       core
#
# [3089 rows x 5 columns]

# %% [markdown]
# ### .index

# %%
filter = style[style.horizontal=='value'].index
# .indexs()
filter
# Out:
# Int64Index([   0,    4,    7,   12,   18,   21,   22,   25,   27,   37,
#             ...
#             2965, 2973, 2974, 2980, 2984, 3037, 3048, 3050, 3069, 3076],
#            dtype='int64', length=884)

# %% [markdown]
# ### .drop
# axis : {0 or ‘index’, 1 or ‘columns’}, default 0
# Whether to drop labels from the index (0 or ‘index’) or columns (1 or ‘columns’).
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html?highlight=drop#pandas.DataFrame.drop

# %%
style.drop(filter)
# Out:
#       SECURITY_ID_INT       raw_X       raw_Y vertical horizontal
# 1                   4  251.404177  469.568402    large     growth
# 2                   8  241.797552   -7.651046    small     growth
# 3                  10  310.086762   69.951089    small     growth
# 5                  14  202.552752   95.194638    small     growth
# 6                  16  319.352339  228.303999    large     growth
# 8                  19  370.285031   71.223713    small     growth
# 9                  21  245.231469  145.630078      mid     growth
# 10                 24  229.214039  213.537403    large     growth
# 11                 27  217.547296    5.712293    small     growth
# 13                 31  307.993202   47.180633    small     growth
# 14                 33  140.911334  149.106156      mid       core
# 15                 35  225.120801   99.295289    small     growth
# 16                 37  216.232175   61.737654    small     growth
# 17                 39  131.995782  178.453363      mid       core
# 19                 42  196.427229   30.470158    small       core
# 20                 45  435.158430  157.968294      mid     growth
# 23                 50  312.964303  232.425854    large     growth
# 24                 52  351.132229  156.775034      mid     growth
# 26                 56  112.504623  179.690342      mid       core
# 28                 59  235.493535  177.245325      mid     growth
# 29                 60  156.006193  136.746889      mid       core
# 30                 61  180.161431  148.449333      mid       core
# 31                 62  114.718072   68.291813    small       core
# 32                 64  202.699910  153.116518      mid     growth
# 33                 65  167.196644  321.461894    large       core
# 34                 67  292.168158  203.370884    large     growth
# 35                 68  181.965853  152.541734      mid       core
# 36                 69  116.261704  105.748833      mid       core
# 38                 72  257.879522  269.760376    large     growth
# 39                 73  269.537434  123.251741      mid     growth
# ...               ...         ...         ...      ...        ...
# 3057           499951  124.461688   72.232746    small       core
# 3058           504610  318.965839    0.509617    small     growth
# 3059           608872  442.265754   71.499941    small     growth
# 3060           609349  315.788800   28.266672    small     growth
# 3061           643126  447.950597   46.150897    small     growth
# 3062           697375  437.383476   98.024508    small     growth
# 3063           706318  297.749454   13.626934    small     growth
# 3064           720082  482.392971   94.807866    small     growth
# 3065           720408  507.102996   73.238187    small     growth
# 3066           722866  530.968258  118.408305      mid     growth
# 3067           731081  367.668954   71.963050    small     growth
# 3068           841088  359.416606    9.737626    small     growth
# 3070           984382  282.926912   27.808847    small     growth
# 3071         30000186  128.094265  267.550670    large       core
# 3072         30004642  321.823022   32.414554    small     growth
# 3073         30004657  307.281947   45.985362    small     growth
# 3074         30004658  327.565190   16.862841    small     growth
# 3075         30004664  512.740054   70.565145    small     growth
# 3077         30004690  475.533539   48.545333    small     growth
# 3078         30004703  417.981804   63.743232    small     growth
# 3079         30004704  133.410300   23.698856    small       core
# 3080         30004705  521.568351   55.521179    small     growth
# 3081         30004706  431.930095   11.843375    small     growth
# 3082         30005207  258.001936  226.612383    large     growth
# 3083         30011845  515.683759   51.987300    small     growth
# 3084         30011852  279.934828   24.220374    small     growth
# 3085         30011859  330.412682   23.172880    small     growth
# 3086         30011864  507.286792  103.169565      mid     growth
# 3087         30011866  399.720301   21.900410    small     growth
# 3088         30011876  189.041079   62.886531    small       core
#
# [2205 rows x 5 columns]

# %%
style.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3089 entries, 0 to 3088
# Data columns (total 5 columns):
# SECURITY_ID_INT    3089 non-null int64
# raw_X              3089 non-null float64
# raw_Y              3089 non-null float64
# vertical           3089 non-null object
# horizontal         3089 non-null object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 120.7+ KB

# %%
style[style.horizontal=='value']
style[style.horizontal=='value']
# Out:
#       SECURITY_ID_INT       raw_X       raw_Y vertical horizontal
# 0                1734 -106.512730  223.595615    large      value
# 1                1351  -95.753155  244.328818    large      value
# 2                2228  -74.231371  318.054976    large      value
# 3                2296  -57.797931  394.503697    large      value
# 4                1971  -50.873616  581.970420    large      value
# 5                 596  -48.216841  350.745190    large      value
# 6                1768  -34.912216  264.474972    large      value
# 7                 599  -31.074632  369.757377    large      value
# 8                1441  -27.497806  311.781603    large      value
# 9               11293  -21.570914  327.138403    large      value
# 10               2056  -19.671819  640.353763    large      value
# 11               2196  -13.072381  496.736476    large      value
# 12               1540   -9.733348  292.741409    large      value
# 13               2076   -9.548853  302.221132    large      value
# 14               2139   -5.720733  319.502015    large      value
# 15               3333   -4.434994  587.689288    large      value
# 16               1287   -2.610981  235.501734    large      value
# 17                601   -1.555074  459.172547    large      value
# 18               1200    2.999047  229.421634    large      value
# 19              30871    5.496519  277.656112    large      value
# 20              30872    5.871399  230.468421    large      value
# 21                342    8.939300  265.541542    large      value
# 22              30866   10.598804  365.931226    large      value
# 23                743   13.632366  254.565113    large      value
# 24                786   16.046880  299.483917    large      value
# 25              30868   17.419317  341.568721    large      value
# 26                641   17.604048  298.931720    large      value
# 27               2116   19.575534  472.223538    large      value
# 28               2517   24.736779  360.985807    large      value
# 29                182   28.252149  259.153746    large      value
# ...               ...         ...         ...      ...        ...
# 2280             1318   90.703749  158.983102      mid      value
# 2281             4713   90.961000  155.352809      mid      value
# 2282             3600   90.968185  192.502702      mid      value
# 2283              620   90.984035  199.849452      mid      value
# 2284             1100   91.021158  111.980026      mid      value
# 2285             1050   92.663875  126.192626      mid      value
# 2286              833   93.708837  186.604578      mid      value
# 2287             3650   93.925420  166.820213      mid      value
# 2288              361   94.105557  107.187794      mid      value
# 2289            29100   94.322359  113.519853      mid      value
# 2290             3463   94.951557  171.278483      mid      value
# 2291              894   95.234606  157.846744      mid      value
# 2292             3221   95.279416  183.617690      mid      value
# 2293            30492   95.298367  176.881800      mid      value
# 2294              704   95.408540  112.611867      mid      value
# 2295              431   95.501543  109.844361      mid      value
# 2296             1777   95.577317  156.837938      mid      value
# 2297             4136   95.707184  163.397386      mid      value
# 2298             2090   95.763762  102.409349      mid      value
# 2299              166   96.168854  160.072654      mid      value
# 2300              303   96.609284  158.734964      mid      value
# 2301              665   96.880049  157.249927      mid      value
# 2302               76   97.289067  115.113982      mid      value
# 2303             3553   97.763135  115.784939      mid      value
# 2304              470   98.742283  136.171268      mid      value
# 2305             3450   98.747536  105.117875      mid      value
# 2306             2728   98.834687  148.523188      mid      value
# 2307              177   98.836469  174.186306      mid      value
# 2308               17   99.307138  185.975849      mid      value
# 2309              474   99.770440  166.967477      mid      value
#
# [884 rows x 5 columns]

# %%
style.head(5)
# Out:
#    SECURITY_ID_INT       raw_X       raw_Y vertical horizontal
# 0                2   54.546833  432.316244    large      value
# 1                4  251.404177  469.568402    large     growth
# 2                8  241.797552   -7.651046    small     growth
# 3               10  310.086762   69.951089    small     growth
# 4               12   -8.259759  171.692515      mid      value

# %% [markdown]
# ### .groupby

# %%
# to calculate the mean of vertical group
dfgroup = style[['raw_X','raw_Y','vertical']].groupby(['vertical']).agg(['mean', 'std'])
# dfgroup = style.groupby(['vertical']).agg(['mean', 'std'])

dfgroup
# Out:
#                raw_X                   raw_Y
#                 mean         std        mean        std
# vertical
# large     200.941888   98.033842  276.059847  76.808567
# mid       154.432431  132.723943  142.928277  28.416332
# small     161.970242  140.382012   55.174502  28.432147

# %%
dfgroup.columns
# Out:
# MultiIndex(levels=[[u'raw_X', u'raw_Y'], [u'mean', u'std']],
#            labels=[[0, 0, 1, 1], [0, 1, 0, 1]])

# %% [markdown]
# ### .droplevel

# %%
dfgroup.columns.droplevel(0)
# dfgroup.columns.droplevel(1)
# Out:
# Index([u'mean', u'std', u'mean', u'std'], dtype='object')

# %%
tdf = dfgroup
tdf.columns = dfgroup.columns.droplevel(0)
tdf
# Out:
#                 mean         std        mean        std
# vertical
# large     200.941888   98.033842  276.059847  76.808567
# mid       154.432431  132.723943  142.928277  28.416332
# small     161.970242  140.382012   55.174502  28.432147

# %% [markdown]
# # reshape
# https://pandas.pydata.org/pandas-docs/stable/reshaping.html?highlight=reshape

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two', 'two'],
                    'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                    'baz': [1, 2, 3, 4, 5, 6],
                    'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df
# Out:
#   bar  baz  foo zoo
# 0   A    1  one   x
# 1   B    2  one   y
# 2   C    3  one   z
# 3   A    4  two   q
# 4   B    5  two   w
# 5   C    6  two   t

# %% [markdown]
# ### stack

# %%
df.stack()
# type(df.stack())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### pivot
# Return reshaped DataFrame organized by given index / column values

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two', 'two'],
                    'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                    'baz': [1, 2, 3, 4, 5, 6],
                    'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df
# Out:
#   bar  baz  foo zoo
# 0   A    1  one   x
# 1   B    2  one   y
# 2   C    3  one   z
# 3   A    4  two   q
# 4   B    5  two   w
# 5   C    6  two   t

# %%
df.pivot(index='foo', columns='bar', values='baz')
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df.pivot(index='foo', columns='bar')
# Out:
#     baz       zoo
# bar   A  B  C   A  B  C
# foo
# one   1  2  3   x  y  z
# two   4  5  6   q  w  t

# %%
style.head()
# Out:
#    SECURITY_ID_INT       raw_X       raw_Y vertical horizontal
# 0                2   54.546833  432.316244    large      value
# 1                4  251.404177  469.568402    large     growth
# 2                8  241.797552   -7.651046    small     growth
# 3               10  310.086762   69.951089    small     growth
# 4               12   -8.259759  171.692515      mid      value

# %%
tdf = style[['raw_X','vertical', "horizontal"]].groupby(['vertical', "horizontal"]).agg(['mean', 'std'])
tdf
# Out:
#                           raw_X
#                            mean        std
# vertical horizontal
# large    core        158.110646  28.411360
#          growth      275.452098  59.665463
#          value        37.743257  49.014845
# mid      core        149.649329  27.631831
#          growth      294.043388  82.117999
#          value         9.578589  72.477051
# small    core        148.720487  28.980646
#          growth      310.230074  96.886996
#          value        14.360988  68.333564

# %%
tdf.columns = tdf.columns.droplevel(0)
tdf
# Out:
#                            mean        std
# vertical horizontal
# large    core        158.110646  28.411360
#          growth      275.452098  59.665463
#          value        37.743257  49.014845
# mid      core        149.649329  27.631831
#          growth      294.043388  82.117999
#          value         9.578589  72.477051
# small    core        148.720487  28.980646
#          growth      310.230074  96.886996
#          value        14.360988  68.333564

# %%
tdf = tdf.reset_index()
tdf
# Out:
#   vertical horizontal        mean        std
# 0    large       core  158.110646  28.411360
# 1    large     growth  275.452098  59.665463
# 2    large      value   37.743257  49.014845
# 3      mid       core  149.649329  27.631831
# 4      mid     growth  294.043388  82.117999
# 5      mid      value    9.578589  72.477051
# 6    small       core  148.720487  28.980646
# 7    small     growth  310.230074  96.886996
# 8    small      value   14.360988  68.333564

# %%
tdf.pivot(index="vertical", columns="horizontal")
# Out:
#                   mean                               std
# horizontal        core      growth      value       core     growth      value
# vertical
# large       158.110646  275.452098  37.743257  28.411360  59.665463  49.014845
# mid         149.649329  294.043388   9.578589  27.631831  82.117999  72.477051
# small       148.720487  310.230074  14.360988  28.980646  96.886996  68.333564

# %% [markdown]
# ### .shift

# %% [markdown]
# ### .unique
